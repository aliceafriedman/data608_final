# %% [markdown]
# ## Data Acquisition
#
# First I will use the `sodapy` package to set up a data stream using the Open Data API. This data is updated monthly, and so by using an API, the data will always be up-to-date.

# %%
import pandas as pd
import datetime
import csv_to_geojson

# %%
import json

# %%
summons_raw = pd.read_csv("~/data608_final/docs/scratch/NYPD_Criminal_Court_Summons__Historic_.csv")

# %%
summons_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5280675 entries, 0 to 5280674
# Data columns (total 17 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   SUMMONS_KEY            int64
#  1   SUMMONS_DATE           object
#  2   OFFENSE_DESCRIPTION    object
#  3   LAW_SECTION_NUMBER     object
#  4   LAW_DESCRIPTION        object
#  5   SUMMONS_CATEGORY_TYPE  object
#  6   AGE_GROUP              object
#  7   SEX                    object
#  8   RACE                   object
#  9   JURISDICTION_CODE      int64
#  10  BORO                   object
#  11  PRECINCT_OF_OCCUR      int64
#  12  X_COORDINATE_CD        float64
#  13  Y_COORDINATE_CD        float64
#  14  Latitude               float64
#  15  Longitude              float64
#  16  Lon_Lat                object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 684.9+ MB

# %%
cols = ['SUMMONS_KEY', 'PRECINCT_OF_OCCUR','OFFENSE_DESCRIPTION', 'RACE', 'AGE_GROUP', 'SEX','Latitude', 'Longitude']

df = summons_raw[cols].assign(
    SUMMONS_DATE = pd.to_datetime(summons_raw['SUMMONS_DATE'], infer_datetime_format=True)
).fillna('')

# %%
cond = df['OFFENSE_DESCRIPTION'].str.contains("MARIJUANA")
mj_summons_2006_2019 = df[cond]

# %% [markdown]
# Now to convert this dataframe to geojson so it can be mapped with a structure like the below:
#
# 0 {'geometry': {'type': 'Point', 'coordinates': [-70.5867, -29.9953, 760]}, 'type': 'Feature', 'properties': {'name': 'A', 'description': 'Place a'}}

# %%
#https://gis.stackexchange.com/questions/220997/pandas-to-geojson-multiples-points-features-with-python <-found here
#https://geoffboeing.com/2015/10/exporting-python-data-geojson/ <- adapted from here
def df_to_geojson(df, properties, lat='Latitude', lon='Longitude'):
    geojson = {'type':'FeatureCollection', 'features':[]}
    for _, row in df.iterrows():
        feature = {'type':'Feature',
                   'properties':{},
                   'geometry':{'type':'Point','coordinates':[]}}
        feature['geometry']['coordinates'] = [row[lon],row[lat],0]
        for prop in properties:
            feature['properties'][prop] = row[prop]
        geojson['features'].append(feature)
    return geojson

cols = ['SUMMONS_DATE','PRECINCT_OF_OCCUR','OFFENSE_DESCRIPTION', 'RACE', 'AGE_GROUP', 'SEX']
summons_geojson = df_to_geojson(mj_summons_2006_2019, cols)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-88-8bf9d5c33e29> in <module>
#      14
#      15 cols = ['SUMMONS_KEY', 'PRECINCT_OF_OCCUR','OFFENSE_DESCRIPTION', 'RACE', 'AGE_GROUP', 'SEX']
# ---> 16 summons_geojson = df_to_geojson(mj_summons_2006_2019, cols)
#
# <ipython-input-88-8bf9d5c33e29> in df_to_geojson(df, properties, lat, lon)
#       9         feature['geometry']['coordinates'] = [row[lon],row[lat],0]
#      10         for prop in properties:
# ---> 11             feature['properties'][prop] = row[prop]
#      12         geojson['features'].append(feature)
#      13     return geojson
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in dtype(self)
#     417         Return the dtype object of the underlying data.
#     418         """
# --> 419         return self._data.dtype
#     420
#     421     @property
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in dtype(self)
#    1548     @property
#    1549     def dtype(self):
# -> 1550         return self._block.dtype
#    1551
#    1552     @property
#
# KeyboardInterrupt:

# %%
with open('/scratch/summons_mj.geojson', 'w') as outfile:
    json.dump(test_geojson, outfile)

# %%
mini_df = df[df['date'] > datetime.datetime(2019, 1, 1)]

# %%
counts = mini_df[['SUMMONS_KEY', 'OFFENSE_DESCRIPTION']].pivot_table(index="OFFENSE_DESCRIPTION", aggfunc='count')

counts[counts['SUMMONS_KEY']>500]
# Out:
#                                                     SUMMONS_KEY
# OFFENSE_DESCRIPTION
# ACCEPT ON HAIL                                              972
# ALCOHOLIC BEVERAGE IN PUBLIC                               2541
# COMMERCIAL VEHICLE; NAME/ADDRESS NOT DISPLAYED              907
# CONGREGATES WITH OTHER PERSONS IN PUBLIC AND RE...          562
# CONSUMPTION OF ALCOHOL                                     1271
# CREATES A HAZARDOUS OR PHYSICALLY OFFENSIVE CON...          513
# DISORDERLY CONDUCT                                         1092
# ENGAGES IN FIGHTING, OR VIOLENT, TUMULTUOUS OR ...         1576
# EQUIPMENT                                                  1117
# FEDERAL MOTOR VEH. SAFETY REG                             24563
# HIGHWAY USE TAX (NYS)                                       753
# LICENSE, OPERATE WITH SUSPENDED/REVOKED/NONE                567
# MARIJUANA, POSSESSION OF                                  10382
# MARIJUANA, UNLAWFUL POSSESSION 2ND DEGREE                  4439
# MOTOR VEHICLE; ENGINE ON/KEY IN IGNITION (THERE...         1147
# NO TAX STAMP                                               1850
# NON PAYMENT OF FARE (OTHER)                                2232
# OBSTRUCTS VEHICULAR OR PEDESTRIAN TRAFFIC                  1297
# OPERATION WHILE REGISTRATION OR PRIVILEGE IS SU...         3032
# OTHER NYS TRANSPORTATION                                   1404
# OTHER TRAFFIC REG                                          1469
# OTHER TRANSIT REG                                           712
# RECKLESS DRIVING                                           1501
# TRESPASS                                                   2109

# %%
code_map = {
    "ABC":"Alcoholic Beverage Control",
    "TLC": "Taxi & Limousine", #Business Violations?
}

# %%
mini_df[mini_df['SUMMONS_CATEGORY_TYPE'] == 'NYS TRANS']['OFFENSE_DESCRIPTION'].unique() #speeding
# Out:
# array(['FEDERAL MOTOR VEH. SAFETY REG', 'OTHER NYS TRANSPORTATION'],
#       dtype=object)

# %%
mini_df[mini_df['SUMMONS_CATEGORY_TYPE'] == 'TLC']['OFFENSE_DESCRIPTION'].unique()
# Out:
# array(['ACCEPT ON HAIL', 'NO TAX STAMP', 'PICK UP FROM BUS STOP',
#        'UNLICENSED VEHICLE FOR HIRE',
#        'FAIL TO COMPLY WITH TLC REGULATIONS', 'IDLING OF VEHICLE',
#        'PICK UP FARE IN STREET PROHIBITED ("CRUISING")',
#        'PICK UP HAIL IN BUS STOP', 'NO TRIP SHEET',
#        'NO CHAUFFEURS LICENSE (CLASS E)', 'NO MEDALLION',
#        'UNAUTHORIZED SIGNS (TAXI, CAR SERVICE)',
#        'INSURANCE STAMP EXPIRED', 'UNAUTHORIZED RADIO'], dtype=object)

# %%
mini_df[mini_df['SUMMONS_CATEGORY_TYPE'] == 'VTL']['OFFENSE_DESCRIPTION'].unique()
# Out:
# array(['RECKLESS DRIVING', 'EQUIPMENT', 'UNINSURED VEHICLE',
#        'UNREGISTERED VEHICLE', 'HIGHWAY USE TAX (NYS)',
#        'UNINSPECTED VEHICLE', 'OTHER VTL', 'IMPROPER PLATES',
#        'OVERWEIGHT (VEH)', 'AGG. UNLICENSED OPER.', 'DEFECTIVE HEADLIGHT',
#        'DEFECTIVE REFLECTOR', 'UNLICENSED OPERATOR', 'OBSTRUCTED VIEW',
#        'PICK-UP FARE IN BUS STOP', 'DRIVE ON SIDEWALK',
#        'UNATTENDED VEH. (ENGINE RUNNING)', 'REVOCATION OR SUSPENSION',
#        'DEFECTIVE BREAKLIGHT', 'FAILURE TO YIELD AT INTERSECTION',
#        'FAILURE TO SURRENDER LICENSE OR REGISTRATION', 'ONE WAY STREET',
#        'IMPROPER TURN', 'RED LIGHT (DISOBEY)',
#        'PAVEMENT MARKING (DISOBEY)', 'INVALID PROOF OF INSUR.',
#        'REVOKED REGISTRATION', 'IMPROPER STICKER', 'PASSING ON LEFT',
#        'LEAVING THE SCENE OF AN ACCIDENT (PROP. DAM.)',
#        'CONSUMPTION OF ALCOHOL IN VEHICLE', 'STOP SIGN',
#        'FOLLOWING TOO CLOSELY', 'FAIL TO COMPLY WITH ORDER',
#        'BICYCLE (OTHER)', 'SAFETY BELT (CHILD)',
#        'SCHOOL BUS, PASSING STOPPED',
#        'UNAUTHORIZED USE OF POLICE INSIGNIA', 'UNSAFE LANE CHANGE',
#        'BROKEN WINDSHIELD'], dtype=object)

# %%
mini_df[mini_df['SUMMONS_CATEGORY_TYPE'] == 'OTHER ABC'].groupby('OFFENSE_DESCRIPTION').count()
# Out:
#                                       PRECINCT_OF_OCCUR  \
# OFFENSE_DESCRIPTION
# OTHER ABC                                           416
# OTHER ACA                                            18
# OTHER BUSINESS LAW                                  163
# OTHER ENVIRONMENTAL CONSERVATION LAW                 10
# OTHER HEALTH CODE                                   116
# OTHER MULTIPLE DWELLING                               2
# OTHER NAVIGATION LAW                                133
# OTHER NYS EDUCATION LAW                               1
# OTHER NYS WORK COMP                                   6
# OTHER SANITARY CODE                                  55
# OTHER TAX LAW                                       356
# OTHER TLC                                            40
# OTHER TRAFFIC REG                                  1469
# OTHER TRANSIT REG                                   712
#
#                                       SUMMONS_CATEGORY_TYPE  X_COORDINATE_CD  \
# OFFENSE_DESCRIPTION
# OTHER ABC                                               416              416
# OTHER ACA                                                18               18
# OTHER BUSINESS LAW                                      163              163
# OTHER ENVIRONMENTAL CONSERVATION LAW                     10               10
# OTHER HEALTH CODE                                       116              116
# OTHER MULTIPLE DWELLING                                   2                2
# OTHER NAVIGATION LAW                                    133              133
# OTHER NYS EDUCATION LAW                                   1                1
# OTHER NYS WORK COMP                                       6                6
# OTHER SANITARY CODE                                      55               55
# OTHER TAX LAW                                           356              356
# OTHER TLC                                                40               40
# OTHER TRAFFIC REG                                      1469             1469
# OTHER TRANSIT REG                                       712              712
#
#                                       Y_COORDINATE_CD  date
# OFFENSE_DESCRIPTION
# OTHER ABC                                         416   416
# OTHER ACA                                          18    18
# OTHER BUSINESS LAW                                163   163
# OTHER ENVIRONMENTAL CONSERVATION LAW               10    10
# OTHER HEALTH CODE                                 116   116
# OTHER MULTIPLE DWELLING                             2     2
# OTHER NAVIGATION LAW                              133   133
# OTHER NYS EDUCATION LAW                             1     1
# OTHER NYS WORK COMP                                 6     6
# OTHER SANITARY CODE                                55    55
# OTHER TAX LAW                                     356   356
# OTHER TLC                                          40    40
# OTHER TRAFFIC REG                                1469  1469
# OTHER TRANSIT REG                                 712   712

# %%
mini_df[mini_df['SUMMONS_CATEGORY_TYPE'] == 'KNIFE']['OFFENSE_DESCRIPTION'].unique()
# Out:
# array(['KNIFE, ANY IN PUBLIC VIEW', 'POSS. OF KNIFE', 'BOX CUTTER'],
#       dtype=object)

# %%
mini_df[mini_df['SUMMONS_CATEGORY_TYPE'] == 'AIR GUN']['OFFENSE_DESCRIPTION'].unique()
# Out:
# array(['POSS. OF MACE', 'IMITATION PISTOL/AIR RIFLE, POSS. OF'],
#       dtype=object)

# %%
mini_df[mini_df['SUMMONS_CATEGORY_TYPE'] == 'FOOD']['OFFENSE_DESCRIPTION'].unique()
# Out:
# array(['BARE HAND CONTACT (FOOD)'], dtype=object)

# %% [markdown]
# new_names = [col.lower() for col in mini_df.columns]
# mini_df.columns = new_names
# loc = "~/data608_final/docs/scratch/mini_df."
# mini_df.to_csv(loc+"csv")
# mini_df.to_json(loc+"json")

# %%
mini_df.pivot_table(index="PRECINCT_OF_OCCUR", columns='SUMMONS_CATEGORY_TYPE', aggfunc='count', margins=True)
# Out:
#                       OFFENSE_DESCRIPTION                                 \
# SUMMONS_CATEGORY_TYPE                 ABC AIR GUN ALCOHOL AMMO AVIGATION
# PRECINCT_OF_OCCUR
# 1                                     NaN     NaN     NaN  NaN       2.0
# 5                                     1.0     NaN     6.0  NaN       NaN
# 6                                     3.0     1.0     2.0  NaN       NaN
# 7                                     1.0     1.0     4.0  NaN       NaN
# 9                                    16.0     NaN     9.0  NaN       NaN
# ...                                   ...     ...     ...  ...       ...
# 120                                   7.0     3.0    68.0  NaN       NaN
# 121                                   7.0     NaN    15.0  NaN       NaN
# 122                                   3.0     1.0     1.0  NaN       NaN
# 123                                   1.0     NaN     NaN  NaN       NaN
# All                                 552.0   122.0  1302.0  8.0       7.0
#
#                                                                         ...  \
# SUMMONS_CATEGORY_TYPE   BIKE BUSINESS DISORDERLY CONDUCT   DOG DUMPING  ...
# PRECINCT_OF_OCCUR                                                       ...
# 1                        NaN      NaN               12.0   NaN     NaN  ...
# 5                       10.0      3.0               15.0   NaN     NaN  ...
# 6                        NaN      1.0               11.0   NaN     NaN  ...
# 7                        1.0      NaN               28.0   NaN     NaN  ...
# 9                        1.0      NaN               21.0   NaN     NaN  ...
# ...                      ...      ...                ...   ...     ...  ...
# 120                      4.0      2.0               22.0   3.0     NaN  ...
# 121                      NaN      4.0               15.0   1.0     NaN  ...
# 122                      1.0      NaN                3.0   4.0     NaN  ...
# 123                      NaN      NaN                6.0   NaN     NaN  ...
# All                    213.0    164.0             1661.0  86.0     1.0  ...
#
#                          date                                          \
# SUMMONS_CATEGORY_TYPE SMOKING SPITTING     TLC TOW TRUCK TRAFFIC REGS
# PRECINCT_OF_OCCUR
# 1                         NaN      NaN   173.0       NaN          1.0
# 5                         NaN      NaN   133.0       NaN          1.0
# 6                         NaN      NaN    14.0       NaN          2.0
# 7                         NaN      NaN   299.0       NaN          6.0
# 9                         NaN      2.0     6.0       NaN          9.0
# ...                       ...      ...     ...       ...          ...
# 120                       NaN      4.0     6.0       NaN          4.0
# 121                       NaN      1.0    10.0       NaN          1.0
# 122                       3.0      NaN     6.0       NaN          3.0
# 123                       NaN      NaN     1.0       1.0          1.0
# All                      18.0    107.0  4072.0      33.0        455.0
#
#
# SUMMONS_CATEGORY_TYPE TRESPASS URINATING VENDING     VTL    All
# PRECINCT_OF_OCCUR
# 1                          8.0       NaN    76.0   333.0   2546
# 5                         50.0       1.0    79.0   243.0   2229
# 6                         13.0       1.0     3.0    25.0    347
# 7                         30.0       NaN   132.0   539.0   4487
# 9                         11.0       1.0     6.0    23.0    392
# ...                        ...       ...     ...     ...    ...
# 120                       30.0      21.0     2.0    12.0    545
# 121                      119.0       2.0     1.0    18.0    483
# 122                       11.0       NaN     1.0     5.0    977
# 123                       10.0       NaN     1.0     3.0    211
# All                     2109.0     184.0  1259.0  5419.0  64319
#
# [78 rows x 180 columns]

# %%
mini_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 608122 entries, 3953 to 2323838
# Data columns (total 4 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   offense_description  608110 non-null  object
#  1   x_coordinate_cd      608122 non-null  float64
#  2   y_coordinate_cd      608122 non-null  float64
#  3   date                 608122 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 23.2+ MB

# %%
mini_df.head()
# Out:
#                  offense_description  x_coordinate_cd  y_coordinate_cd  \
# 3953                        TRESPASS        1009438.0         184799.0
# 4580   FEDERAL MOTOR VEH. SAFETY REG        1015107.0         214443.0
# 5236                       EQUIPMENT        1002064.0         229163.0
# 8597                       EQUIPMENT         988082.0         200814.0
# 10447              OTHER TRAFFIC REG         982886.0         202795.0
#
#             date
# 3953  2018-09-28
# 4580  2018-10-11
# 5236  2018-09-13
# 8597  2018-11-08
# 10447 2018-11-29

# %%
mini_df['offense_description'].unique()
# Out:
# array(['TRESPASS', 'FEDERAL MOTOR VEH. SAFETY REG', 'EQUIPMENT',
#        'OTHER TRAFFIC REG', 'MARIJUANA, POSSESSION OF',
#        'RECKLESS DRIVING', 'UNINSPECTED VEHICLE', 'UNINSURED VEHICLE',
#        'OTHER VTL', 'PUBLIC URINATION', 'OTHER ABC', 'OTHER BUSINESS LAW',
#        'CRUELTY TO ANIMAL(S)', 'OTHER TAX LAW', 'FOR GAMBLING',
#        'LITTERING PROHIBITED', 'DEFECTIVE REFLECTOR', 'ACCEPT ON HAIL',
#        'FAILURE TO COMPLY WITH SIGN', 'PERMIT UNLICENSED',
#        'REVOKED REGISTRATION', 'OTHER TRANSIT REG', 'CAB HAILER',
#        'KEY IN IGNITION', 'REVOCATION OR SUSPENSION', 'OVERWEIGHT (VEH)',
#        'PICK-UP FARE IN BUS STOP', 'UNREGISTERED VEHICLE',
#        'IMPROPER PLATES', 'UNLICENSED CABARET', 'DISORDERLY PREMISE',
#        'UNDERAGE DRINKING', 'CONSUMPTION OF ALCOHOL', 'OTHER TLC',
#        'IMPROPER STICKER', 'PICK UP FROM BUS STOP', 'POSS. OF KNIFE',
#        'ILLEGAL BOTTLE CLUB', 'DOG: UNLEASHED', 'PARK REGULATIONS',
#        'DISCON: CREATE HAZARDOUS CONDITION', 'LITTERING',
#        'DISOBEY TRANSIT SIGN', 'NO TAX STAMP',
#        'NON PAYMENT OF FARE (OTHER)', 'HIGHWAY USE TAX (NYS)',
#        'AGG. UNLICENSED OPER.', 'LITTERING FROM VEHICLE',
#        'OTHER SANITARY CODE', 'ALCOHOLIC BEVERAGE IN PUBLIC',
#        'DISORDERLY CONDUCT',
#        'SOLICITING AT SCENE; UNREASONABLE/UNNECESSARY',
#        'POSSESSION OF AN IMITATION PISTOL (TOY) THAT LOOKS REAL',
#        'OBSTRUCTS VEHICULAR OR PEDESTRIAN TRAFFIC',
#        'ENGAGES IN FIGHTING, OR VIOLENT, TUMULTUOUS OR THREATENING BEHAVIOR',
#        'EVICTION; UNLAWFUL (INTERRUPT ESSENTIAL SERVICES)',
#        'IMPROPERLY OR UNMARKED BEER TAP',
#        'OPERATION WHILE REGISTRATION OR PRIVILEGE IS SUSPENDED OR REVOKED',
#        'LICENSE, OPERATE WITH SUSPENDED/REVOKED/NONE',
#        'DISPLAY OF PEDICAB DRIVER?S IDENTIFICATION',
#        'MOTOR VEHICLE; ENGINE ON/KEY IN IGNITION (THERE IS NO TIME REQUIREMENT)',
#        'BUSINESS NAME NOT DISPLAYED ON THE OUTSIDE', 'JAYWALKING',
#        'DISCON: REFUSE LAWFUL ORDER', 'OTHER NYS TRANSPORTATION',
#        'CREATES A HAZARDOUS OR PHYSICALLY OFFENSIVE CONDITION WITHOUT A LEGITIMATE PURPO',
#        'WAREHOUSING ALCOHOL WITHOUT A PERMIT', 'DEFECTIVE HEADLIGHT',
#        'SMOKING IN TRAIN STATION', 'IMPROPER ENTRANCE/EXIT',
#        'UNLICENSED VEHICLE FOR HIRE',
#        'PEDICAB WITHOUT EXTIOR SIGN OF RATES',
#        'LIQUOR LICENSE NOT POSTED IN A CONSPICUOUS PLACE',
#        'SALE TO AN INTOXICATED PERSON', 'PEDICAB DRIVER LICENSE',
#        'OTHER ADMIN CODE', 'DISCON: OBSTRUCT VEHICLE',
#        'FIREWORKS, POSSESS/USE', 'VENDOR: FAIL TO DISPLAY PERMIT',
#        'OPERATE WITHOUT BATTERY OPERATED HEADLIGHTS', 'OTHER HEALTH CODE',
#        'OVER CROWDED BAR', 'KNIFE, ANY IN PUBLIC VIEW',
#        'KNIVES; PUBLIC POSSESSION (BLADE 4 INCHES OR MORE)',
#        'MARIJUANA, UNLAWFUL POSSESSION 2ND DEGREE',
#        'DISCON: OBSCENE LANGUAGE/GESTURE', 'OBSTRUCTED VIEW OF PREMISE',
#        'AFTER HOURS CONSUMPTION',
#        'EVICTION; UNLAWFUL (REMOVE PROPERTY/REMOVE DOOR/CHANGE OR DAMAGE LOCKS)',
#        'AIR PISTOL/RIFLE; SELL OR POSSESS', 'EXPOSURE OF PERSON',
#        'BICYCLE ON SIDEWALK', 'FAIL TO COMPLY WITH TLC REGULATIONS',
#        'COMMERCIAL VEHICLE; NAME/ADDRESS NOT DISPLAYED',
#        'NON PAYMENT OF FARE (BUS)', 'NO "BOOK OF DAILY ACTIVITIES"',
#        'CONGREGATES WITH OTHER PERSONS IN PUBLIC AND REFUSES TO DISPERSE BY LAWFUL POLIC',
#        'OPEN FIRE', 'IDLING OF VEHICLE', 'BOX CUTTER',
#        'EMPLOY BOUNCER (SECURITY GUARD) WITHOUT VALID REGISTRATION CARD',
#        'PANHANDLING WITHIN 10 FT. OF BANK/ATM/CHECK CASHING BUSINESS',
#        'FAIL TO DISPLAY LICENSE', 'BICYCLE INFRACTION (COMMERCIAL)',
#        'SALE TO A MINOR (UNDER 21)',
#        'FAIL TO MAINTAIN FIRE EXTINGUISHER INSPECTION',
#        'RESTRICTIONS ON THE OPERATION OF PEDICABS',
#        'HOURS; PERMITTED TO BE IN PARK BETWEEN 6AM-1AM (UNLESS OTHERWISE POSTED)',
#        'OTHER PENAL LAW',
#        'OPERATE PEDICAB WITHOUT BATTERY OPERATED TAIL LIGHTS',
#        'NOISE (DEVICE)', 'STREET, OBSTRUCTED WITH OTHER THAN VEHICLE',
#        'NO PARKING', 'UNREASONABLE NOISE; FROM ANY VEHICLE HORN',
#        'UNLICENSED OPERATOR', 'POSS. OF MACE',
#        'NO SECURITY GUARD LICENSE', 'OBSTRUCTED VIEW INTO BAR',
#        'POLICE UNIFORM/EMBLEM; UNLAWFUL USE OF',
#        'UNREASONABLE NOISE (FROM PERSON)',
#        'PICK UP FARE IN STREET PROHIBITED ("CRUISING")',
#        'RECEIVING MONEY OUTSIDE DAZ', 'POSSESSION OF A POLICE EMBLEM',
#        'OTHER NAVIGATION LAW',
#        'UNREASONABLE NOISE; FROM CAR MUFFLER/EXHAUST (HEARD FROM 150 FT AWAY)',
#        'SPITTING', 'OBSTRUCTED VIEW', 'DISCON: FIGHTING',
#        'PICK UP HAIL IN BUS STOP', 'POSSESSION OF FIREWORKS',
#        'RECKLESS OPERATION OF A BICYCLE *( C SUMMONS)*', 'DOUBLE PARKING',
#        'FAIL TO CHECK ID', 'UNSECURED COMPRESSED GAS TANKS',
#        'OPEN FIRE (CAUSE OR PERMIT)',
#        'IMITATION PISTOL/AIR RIFLE, POSS. OF',
#        'NO NAME OR ADDRESS DISPLAYED', 'PEDICAB WITHOUT WHEEL REFLECTORS',
#        'DISOBEY ANY PARK SIGN', 'MAKES UNREASONABLE NOISE', 'PANHANDLING',
#        'OBSTRUCTED FIRE EXTINGUISHER',
#        'LICENSE/RECORDS/DOCUMENTS; FAIL TO PRODUCE WHEN REQUESTED',
#        'NOISE (ENGINE EXHUST)', 'URINATING IN PUBLIC',
#        'ALCOHOL IN THE PARK',
#        'POSSESSION OF A BOX CUTTER (20 YES OLD OR YOUNGER)',
#        'SIDEWALK, OBSTRUCTED',
#        'FAIL TO DISPLAY "CERTIFICATE OF OCCUPANCY"',
#        'TICKET SELLERS OBSTRUCT PED FLOW',
#        'IN A PUBLIC PLACE AND USES ABUSIVE/OBSCENE LANGUAGE OR MAKES AN OBSCENE GESTURE',
#        'NO TRIP SHEET', 'SALE TO A MINOR',
#        'POLICE/PRESS CARD; UNLAWFUL USE OR POSSESSION OF',
#        'NO POSTING WORKERS COMP INS', 'UNLICENSED GENERAL VENDOR',
#        'UNLICENSED SALE OF ALCOHOL',
#        'FAILURE TO CONSPICUOUSLY POST "SLA LICENSE" IN A SUITABLE FRAME',
#        'HARASSMENT 2', 'CONSUMPTION OF ALCOHOL IN PARK',
#        'OCCUPANCY SIGN NOT POSTED',
#        'RADIO, TWO-WAY; PROHIBITED WITHOUT PERMIT', 'DRIVE ON SIDEWALK',
#        'TOW TRUCK VIOLATIONS (OTHER)',
#        'UNLICENSED CABARET, DANCE HALL, OR CATERING HALL',
#        'SPITTING IN PUBLIC', 'NO CPR KIT', 'FAIL TO DISPLAY',
#        'POLICE MACE; UNLAWFUL POSSESSION',
#        'UNLAWFUL SALE FOR OFF-PREMISE CONSUMPTION',
#        'PEDESTRIAN FLOW ZONE', 'SELLING OUTSIDE DAZ',
#        'FAIL TO MAINTAIN EMERGENCY LIGHTING',
#        'BARBER/HAIRSTYLIST NOT WEARING OUTER COAT OR UNIFORM',
#        'DRIVER CANNOT PRODUCE PROOF OF INSURANCE', 'LOITERING (GAMBLING)',
#        'NOISE (UNREASONABLE)', 'USING EXTENSION CORD AS PERMANENT WIRING',
#        'SELL ALCOHOLIC BEVERAGES WITHOUT LICENSE',
#        'POSSESSION OF ALCOHOL BY A MINOR',
#        'PISTOL, TOY/IMITATION; UNLAWFUL SALE, USE, ETC.',
#        'HANDCUFFS; UNLAWFUL POSSESSION OF (INCLUDES DISP. CINCH & THUMB CUFFS/LEG IRONS)',
#        'UNLAWFUL POSSESSION SYTHETIC CANNABINOIDS',
#        'FAIL TO MAINTAIN MEANS OF EGRESS', 'TICKETS OUTSIDE DAZ',
#        'CART MAN, UNLICENSED', 'CROSSWALK', 'DISCON: OBSTRUCT PEDESTRIAN',
#        'GLASS BOTTLE/CONTAINER; IN RESTRICTED AREA',
#        'UNATTENDED VEH. (ENGINE RUNNING)',
#        'SMOKING IN AN ENCLOSED SPACE FOR 50 OR MORE PEOPLE',
#        'PERMIT ON-PREMISE CONSUMPTION', 'REFUSE INSPECTION BY POLICE',
#        'KNIVES; DISPLAYED OUTSIDE CLOTHING/CARRY IN THE OPEN WITHOUT A LAWFUL PURPOSE',
#        'PRICES OF ALCOHOL NOT DISPLAYED', 'SMOKING IN A SUPERMARKET',
#        'VENTILATION GRILL, CELLAR DOOR, MANHOLE COVER (STANDING OVER)',
#        'NOISE (HORN/ALARM)', 'REQUIRED EQUIPMENT OF PEDICABS',
#        'FAIL TO POST SIGN - "PROHIBITED SALE TO MINOR/INTOX PERSON"',
#        'SALE OF SPRAY PAINT/BROAD TIPPED MARKER(TO PERSON UNDER 21 YEARS OLD)',
#        'TOW:UNAUTHORIZED REMOVAL OF VEHICLE', 'NO JUNCTION BOX COVERS',
#        'FAIL TO COMPLY WITH VACATE ORDER',
#        'TICKET SELLER WITHIN 10 FT OF X-WALK', 'SALE OF LOOSE CIGARETTES',
#        'VEHICLE; RIFLE/SHOTGUN/AMMO IN', 'OTHER PARK REGS',
#        'UNLEASHED DOG WITH LEASH OVER 6 FEET', 'FAIL TO CONTROL CROWD',
#        'DCA PEDICAB DRIVERS LICENSE NOT VISABLE',
#        'SALE OF ALCOHOL TO A MINOR', 'UNREASONABLE NOISE; GENERAL',
#        'UN-MOUNTED FIRE EXTINGUISHER', 'MISSING EQUIPMENT',
#        'SALE BETWEEN 3AM-12PM ON SUNDAY',
#        'UNREASONABLE NOISE FROM A LICENSED PREMISE',
#        'FAIL TO CLEAN CANINE WASTE', 'NO TOW LICENSE', '20-217(I)',
#        'UNAUTHORIZED POSTING (SIGNS/FLYERS)',
#        'FAILURE TO POST "PREGNANCY WARNING SIGN"', 'DEFECTIVE BREAKLIGHT',
#        'URINATE/DEFICATE IN PARK', 'FOOD PROTECTION/STORAGE/TRANSP',
#        'MERCHANDISE, SALE OF PROHIBITED', 'OTHER ACA',
#        'STREET NUMBERS (ADDRESS) NOT DISPLAYED OUTSIDE',
#        "APPROPRIATE DRIVER'S LICENSE", 'AGGRESSIVE PANHANDLING',
#        'DISORDERLY BEHAVIOR', 'SOUND DEVICE; ADVERTISING PURPOSES',
#        'FAILURE TO YIELD AT INTERSECTION',
#        'UNSOLICITED RESPONSE TO ACCIDENT SCENE',
#        'NO PARKING (EXCEPT AUTH. VEHICLES)',
#        'CROSS MIDDLE OF BLOCK WITH LIGHT SIGNALS AT BOTH ENDS OF STREET',
#        'TICKET SPECULATION (RESELL TICKET TO A VENUE WITH A CAPACITY OF >5000 WITHIN 100',
#        'IN PUBLIC UNDER DRUGS',
#        'FAIL TO MAINTAIN PROPRIETARY SECURITY GUARD LICENSE',
#        'FAILURE TO SURRENDER LICENSE OR REGISTRATION',
#        'BOUNCER (SECURITY GUARD) WITHOUT A VALID REGISTRATION CARD',
#        'DISCON: UNREASONABLE NOISE', 'UNLAWFUL EVICTION',
#        'UNLICENSED BARBER',
#        'GRAFFITI PROHIBITED; PUBLIC/PRIVATE BUILDING/PROPERTY (INCLUDES STICKER/DECAL)',
#        'INSPECTION; PEDICAB REGISTRATION PLATE',
#        'POSSESSION OF A REPLICA NYPD SHIELD', 'FIRE WITHOUT PERMIT',
#        'COUNTERFEIT INSPECTION STICKER',
#        'UNTAXED BEVERAGE POSSESS/CONTROL',
#        'LOITERING (TRANSPORTATION FACILITY/SLEEPING)',
#        'SALE OF TOBACCO/ROLLING PAPERS TO MINOR',
#        'USE OF ROADWAYS, PEDESTRIANS, HORSES, BICYCLES AND LIMITED USE VEHICLES PROHIBIT',
#        'STRIKE, SHOVE, KICK, OR THREATEN/ATTEMPT',
#        'CONTAINER, NOT ORIGINAL OR TAMPERED',
#        'FAILURE TO YIELD TO PEDESTRIAN IN CROSSWALK',
#        'DAZ RULES VIOLATED  CHARACTER', 'SMOKING IN ELEVATOR',
#        'ONE WAY STREET', 'BOOK TO BE OPEN TO INSPECTION',
#        'LITTER FROM A VEHICLE',
#        'EXIT NOT TO STREET OR BLOCKED FROM STREET', 'IMPROPER TURN',
#        'UNLICENSED VEHICLE; KNOWINGLY OPERATE FOR HIRE',
#        'ALCOHOLIC BEVERAGE; CONSUME/POSSESS WITH INTENT TO CONSUME BY SELF/OTHERS',
#        'NO COVERED GARBAGE, USED SOLELY FOR TOWELS AND LINENS',
#        'VENDOR: UNLICENSED', 'NO "NO CHOKING" SIGN IN FOOD ESTABLISHMENT',
#        'SALE AFTER HOURS (4AM-8AM, MON-SAT)', 'IMPROPER REGISTRATION',
#        'DRIVER DOES NOT POSSESS "FOR HIRE-VEHICLE" LICENSE',
#        'BEVERAGES NOT ON LICENSE', 'FOLLOW IN A PUBLIC PLACE',
#        'VACANT LOT; MOTOR VEHICLE PARKED IN',
#        'SERIOUSLY ANNOY WITHOUT A LEGITIMATE PURPOSE',
#        'OTHER NYS WORK COMP', 'ADVERTISE AS HACK WITHOUT LICENSE',
#        'BOTTLE CLUB; OPERATE UNLAWFULLY',
#        'NO CHAUFFEURS LICENSE (CLASS E)',
#        'EXCAVATION (VEHICLE OBSTRUCTING TRAFFIC)',
#        'FAILURE TO DISPLAY PEDICAB REGISTRATION OR PEDICAB DRIVER?S LICENSE',
#        'EXIT LIGHT INOPERABLE',
#        "LICENSE, TOW OPERATOR'S; OPERATE/ASSIST WITHOUT",
#        'AUTHORIZED FIRE; NOT PROPERLY CONTAINED', 'OVERCROWDED',
#        'NO SMOKING SIGN/ NOT POSTED AT ENTRANCE',
#        'SALE/PURCHASE/USE OF ALCOHOL BY MINOR',
#        'DOING BUSINESS UNDER NAME OTHER THAN ON LICENSE',
#        'UNLICENSED TICKET SELLING',
#        'CROSSWALK/DRIVEWAY/ETC, WITHIN 10 FEET',
#        'POLICE RADIO IN AUTO (UNLESS PERMISSION OF POLICE COMMISSIONER IS GRANTED)',
#        'SALE OF TOBACCO TO MINORS (UNDER 18 YEARS OLD)',
#        'SMOKING IN A STORE',
#        'WITHOUT LAWFUL AUTHORITY, DISTURBS ANY LAWFUL ASSEMBLY OR MEETING OF PERSONS',
#        'NO TAX STAMP, NYC', 'RED LIGHT (DISOBEY)',
#        'ONLY 1 EXIT AND OCCUPIED BY MORE THAN 75 PEOPLE',
#        'OWNER UNLICENSED', 'NO FLAME PERMIT FOR CANDLES',
#        'UNLICENSED TICKET SELLER', 'BUS STOP, OBSTRUCT',
#        'NO DOG LICENSE (COLLAR)', 'FIRE HYDRANT, OBSTRUCT',
#        'PEDICAB WITHOUT OPERATIONAL SIGNAL', 'UNLICENSED VENDOR',
#        'SIGNED AUTHORIZATION BY OWNER/POLICE, TOW WITHOUT (REPORT OF VIOLATION PREPARED)',
#        'FAIL TO SECURE WORKERS COMP INS.',
#        'EXCEEDING 12 INCHES FROM CURB',
#        'VENDOR: DISP MERCHANDISE ON SIDEWALK',
#        'FAIL TO DISPLAY CERTIFICATE OF AUTHORITY', 'RULES',
#        'ACCEPTING IMPROPER ID (EX: COLLEGE ID)',
#        'FAILURE TO DISPLAY "BUSINESS CERTIFICATE"',
#        'UNLICENSED SECOND BAR', 'RATES, TOWING; EXCEED AUTHORIZED LIMITS',
#        'UNLICENSED BARBERSHOP', 'NO CPR KIT SIGN',
#        'MARIJUANA, UNLAWFUL POSSESSION 1ST DEGREE', 'OPEN HYDRANT',
#        'FIRE HYDRANT, NEAR', 'TOW:SOLICITING TOW AT SCENE OF ACCIDENT',
#        'POSS. OF RADIO ABLE TO RECEIVE POLICE FREQUENCIES W/O PERMIT FROM POL COMMIS.',
#        'DOG: FAILURE TO REMOVE CANINE WASTE',
#        'CLEAN/WASH/POLISH/OFFER TO PASSENGER VEHICLE',
#        'TRIP SHEET; WITH REQUIRED IDENTIFICATION, DISPATCH INFO AND READINGS',
#        'UNREASONABLE NOISE; FROM MOTORCYCLE MUFFLER/EXHAUST (HEARD FROM 200FT AWAY)',
#        'BARE HAND CONTACT (FOOD)', 'PARKING PROHIBITED',
#        'SOUND DEVICE; NON-COMMERCIAL WITHOUT PERMIT',
#        'SOUND REPRODUCTION DEVICE-NO PERMIT',
#        'CURTAIN PLACED OVER EXIT DOOR',
#        'FAIL TO DISPLAY VALID BUSINESS CERTIFICATE',
#        'TOW TRUCK; RATE/INFO; SIGN NOT POSTED',
#        'NO "CERTIFICATE OF OCCUPANCY"', 'LOITERING (SCHOOL)',
#        'PAVEMENT MARKING (DISOBEY)',
#        'PASSENGER PICK UP IN OMNIBUS FASHION',
#        'CONTAMINATED LIQUORS (EX: FRUIT FLIES IN BOTTLE)',
#        'OTHER THAN CLEAR GLASS WINDOWS', 'INVALID PROOF OF INSUR.',
#        'LITTERING (DUMPING RUBBISH AND REFUSE)',
#        'LIQUIDS (NOXIOUS); POUR/DISCHARGE',
#        'POSSESSION OF AIR PISTOL/RIFLE', 'RATES OF PEDICABS',
#        "CHAUFFER'S LICENSE, OPERATE WITHOUT (NYS OR SIMILAR OF RESIDENT STATE)",
#        'FAIL TO DISPLAY "CABARET LICENSE"',
#        'MEDALLION PLATE; NONE/INSECURE',
#        'LOITERING (TRANSPORTATION FACILITY)', 'UNLICENSED DOG',
#        'REFUSAL TO TOW; WITHIN NYC, UNJUSTIFIABLE (REPORT OF VIOLATION PREPARED)',
#        'NO MEDALLION', 'RECORDS', 'VEHICLE IN PARK',
#        'UNREASONABLE NOISE (FROM SOUND REPRODUCTION DEVICE)',
#        'VENDOR: (OTHER)',
#        'TRIP SHEET; WITH REQUIRED TRIP ENTRIES AND READINGS',
#        'NO BUSINESS CERTIFICATE',
#        'SMOKING ANYPLACE WITH COMBUSTIBLES PRESENT (EX: GAS STATION)',
#        'RECKLESS OPERATION (REPORT OF VIOLATION PREPARED)',
#        'ERECT A SHED', 'SMOKING IN A THEATER/MUSEUM/LIBRARY/HOSPITAL',
#        "TAXICAB DRIVER'S LICENSE; IN APPROPRIATE FRAME",
#        'NO PREGNANCY WARNING SIGN', 'CONTAMINATED ALCOHOL/FOOD',
#        'PEDICAB WITHOUT 311 AND REGISTRATION SIGN',
#        'FAILURE TO DISPLAY "LIQUOR LICENSE"', 'PASSING ON LEFT',
#        'FAILURE TO CONTROL CROWD', 'FAIL TO DISPLAY SERVICE PRICES',
#        'DISORDERLY BEHAVIOR (ENDANGERS SAFETY)', 'RESTRICTED AREA',
#        'SIGNS, UNAUTHORIZED; TAXI, ETC', 'NO "AMUSEMENT ARCADE LICENSE"',
#        'CROSSWALK/DRIVEWAY, ETC',
#        'LEAVING THE SCENE OF AN ACCIDENT (PROP. DAM.)',
#        'FAILURE TO NOTIFY A PRECINCT WITHIN 2 HOURS OF TOWING A VEHICLE WHEN OWNER IS UN',
#        'RESTRICTIONS; FAIL TO COMPLY WITH',
#        'OTHER ENVIRONMENTAL CONSERVATION LAW',
#        'LICENSE, ENGAGE IN TOWING BUSINESS WITHOUT',
#        'RECEIPT; FAIL TO PROVIDE IF REQUESTED',
#        "SCHOOL GROUNDS/SCHOOL BUS/CHILDREN'S OVERNIGHT CAMP WITHOUT LEGITIMATE REASON",
#        'UNAUTHORIZED POSTING', 'CONSUMPTION OF ALCOHOL IN VEHICLE',
#        'HIGHWAY/PARKWAY; UNAUTHORIZED TOW',
#        'PATH, LEAVE LESS THAN 12 FEET (ON SIDEWALK)',
#        'BUS STOP/TAXI STAND, IN', 'REFUSE TO TRANSPORT (WITHIN NYC)',
#        'DRIVER DOES NOT POSSESS "FOR HIRE-VEHICLE" DRIVER\'S LICENSE',
#        'NO EXIT SIGN AT DOOR OR NOT CLEARLY MARKED',
#        'STREET NUMBER NOT DISPLAYED ON ANY BUILDING',
#        'FAIL TO DISPLAY BARBERS/BARBERSHOPS LICENSE',
#        'FAIL TO POST "NO SMOKING" SIGNS WHERE REQUIRED',
#        'DISORDERLY BEHAVIOR (OBSTRUCTS TRAFFIC)', 'PLACE/TIME PROHIBITED',
#        'EXIT DOOR SWINGS IN',
#        'HEADREST NOT COVERED WITH TOWEL OR PAPER TOWEL',
#        'NO SMOKING SIGN POSTED', 'DISORDERLY BEHAVIOR (SEXUAL ACTIVITY)',
#        'NO BARBERS LICENSE', 'EMPLOYMENT OF A MINOR',
#        'REFUSAL TO TOW; VEHICLE OBSTRUCTING TRAFFIC (REPORT OF VIOLATION PREPARED)',
#        'FIRE HYDRANT', 'DUMPING', 'STOP SIGN',
#        'DISCON: DISTURB LAWFUL ASSEMBLY',
#        'VENDOR: FAIL TO DISPLAY PRICES',
#        'UNLAWFULLY POSTING ADVERTISEMENTS', 'NO "DCA CIGARETTE LICENSE"',
#        'NO SMOKING SIGNS NOT POSTED', 'LOITERING (UNCLASSIFIED)',
#        'ALLOW GAMBLING - INSIDE BILLIARD HALL',
#        'POWER DEVICE, ILLEGAL USE OF (GAS/ELECTRIC)',
#        'PATH, LEAVES LESS THAN 12 FT. (ON SIDEWALK)',
#        'POSSESSION OF A WILD ANIMAL',
#        'SOLICITATION OF PEDESTRIANS BY MERCHANT',
#        'ALCOHOL, UNDER INFLUENCE OF (MAY ENDANGER ANYONE/PROPERTY)',
#        'CAR/STAND; OVER 8 FEET LONG, 3 FEET WIDE',
#        'PEDESTRIAN WALKING INTO TRAFFIC UNSAFELY',
#        'FAIL TO COMPLY WITH THE DIRECTIONS OF A POLICE OFFICER',
#        'FOLLOWING TOO CLOSELY', 'LOCKED/BOLTED/FASTENED DOOR',
#        'ENGAGED IN ANY FORM OF SEXUAL ACTIVITY',
#        'STREET; OBSTRUCT WITHOUT PERMIT', 'UNLICENSED REPAIR SHOP',
#        'NO DOG LICENSE (PAPER)', 'FAIL TO WEAR WHILE VENDING',
#        'FAILURE TO DISPLAY VALID NYS "TAX CERTIFICATE OF AUTHORITY"',
#        'OBSTRUCTING TRAFFIC', 'EMPLOYMENT OF A FELON',
#        'SALE OUT OF CLASS', 'PRACTICE OF BARBERING W/O A LICENSE',
#        'UNLAWFUL PREVENTION OF PUBLIC ACCESS TO RECORDS',
#        'ADVERTISE, EXTERIOR, WITHOUT PERMIT',
#        'UNSEALED BOTTLE, LIQUOR/WINE IN AREA (EXCEPT WINE TASTING)',
#        'AMMUNITION; UNLAWFUL SALE/PURCHASE',
#        'BENCH; OBSTRUCT USE FOR OTHER PERSONS',
#        'POSSESSION OF A POLICE SCANNER',
#        'OPERATE MOTOR VEHICLE IN AN UNAUTHORIZED AREA',
#        'FAIL TO COMPLY WITH ORDER', 'EXIT DOOR BLOCKED',
#        'NO OPEN FLAME PERMIT', 'ALLOW ALCOHOL OUTSIDE',
#        'RIFLE, SHOTGUN, AMMO SALE OR PURCHASE',
#        'REGULATIONS, VIOLATE PARKING', 'NO CIGARETTE LICENSE',
#        'CLIMB WALL/FENCE/TREE',
#        'PARK DEPARTMENT PROPERTY; WITHOUT AUTHORIZATION',
#        'NO CERTIFICATE OF OCCUPANCY',
#        "SOLICIT GUARDING OF ANOTHER'S VEHICLE", 'FIRE (WITHOUT PERMIT)',
#        'TAKE OFFS AND LANDING',
#        'NO "BILLIARD & POCKET-BILLIARD ROOM LICENSE"',
#        'UNLICENSED TAXI DRIVER; PERMIT TO OPERATE FOR HIRE',
#        'OFFENSIVE EXHIBITION', 'NO CERTIFICATE OF AUTHORITY',
#        'TRANSIT FACILITY FOR COMMERCIAL OR ENTERTAINMENT PURPOSE',
#        'FIREWORKS',
#        'PERSONAL USE; FAIL TO COMPLY REGARDING TRIP SHEET AND LIGHT',
#        'NO SIGN STATING "CIGARETTE(TOBACCO PRODUCTS)SALE TO PERSONS UNDER 18 PROHIBITED"',
#        'BICYCLE (OTHER)',
#        'VEHICLE DISMANTLER FAILED TO KEEP PROPER RECORDS',
#        'FAILURE TO PRODUCE THE LAST 20 ITEMS FOR INSPECTION',
#        'VEND:RESTRICTIONS ON PLCMENT VEH/PUSHCARTS',
#        'FAILED TO DISPLAY BARBER LICENSE', 'SAFETY BELT (CHILD)',
#        'BUILD/MAINTAIN/USE; OTHER THAN DESIGNATED LOCATION OR WITHOUT A PERMIT',
#        'PUSHCART/STAND/VEHICLE (PERMIT REQUIRED)',
#        'NO NYC LICENSE TO SELL CIGARETTES', 'SCHOOL BUS, PASSING STOPPED',
#        'VENDOR WITHOUT A LICENSE (EXCEPT NEWSPAPERS, PERIODICALS, BOOKS/PAMPHLETS, ETC)',
#        'OPERATE BIKE ON SIDEWALK *(NOT A C SUMMONS)*',
#        'BUSINESS NAME NOT DISPLAYED OUTSIDE',
#        'BICYCLE IN PLAYGROUND; RIDE ON',
#        'PARKED MOTOR VEHICLE, SALE FROM', 'POSSESS WITHOUT PERMIT',
#        'OPERATE BICYCLE IN A RECKLESS MANNER',
#        'DISORDERLY PERSON IN PARK', 'COMPRESSED GAS STORED ON PREMISE',
#        'DOG: UNLICENSED', 'NO CERTIFICATE OF FITNESS FOR AIR COMPRESSOR',
#        'UNAUTHORIZED SIGNS (TAXI, CAR SERVICE)',
#        'PEDI CAB WITHSEATING FOR MORE THAN 3 PASSENGERS',
#        'NO SANITARY SOAP DISPENSER',
#        'SIGNS; FAIL TO OBEY PERTINENT (BICYCLE)', 'UNLEASHED ANIMAL',
#        'STREET NUMBERS (ADDRESS) NOT DISPLAYED ON THE OUTSIDE',
#        'SMOKING IN A CLASSROOM/LECTURE HALL',
#        'ANIMAL/DOG IN PLAYGROUND/PICNIC AREA',
#        'RECEPTACLES; SPILLING FROM', 'UNSEALED BOTTLE PRESENT',
#        'INSURANCE STAMP EXPIRED', 'BIKE IN PARK',
#        'LITTER/CLUTTER AROUND BUILDING', 'ANIMAL BEING A NUISANCE',
#        'CURB, AWAY FROM', 'UNAUTHORIZED USE OF POLICE INSIGNIA',
#        'LITTERNG', 'OTHER NYS EDUCATION LAW', 'PROMOTING EXPOSURE',
#        'LICENSE ALTERED/DEFACED/DESTROYED',
#        'DEFECTIVE; FAIL TO LIGHT "OFF-DUTY" LOCK REAR DOORS, MAKE REQUIRED ENTRIES',
#        'UNSAFE LANE CHANGE', 'POSSESSION OF A SIREN', 'FAIL TO SURRENDER',
#        'DIRTY/OBSTRUCTED SIDEWALK',
#        'SOLICIT PASSENGER; WORDS OTHER THAN "TAXI", "CAB", OR "TAXICAB"',
#        'CLOSE ANY STREET/PORTION, WITHOUT PERMIT',
#        'UNSWEPT/UNMOPPED FLOOR', 'UNINSURED TOW TRUCK',
#        'REPAIR AT SCENE, OFFER TO MAKE OR ESTIMATE COST OF',
#        'OCCUPIED BY OVER 75 PATRONS & NO SPRINKLER SYSTEM',
#        'TICKET SPECULATION: 1-4 TICKETS', 'REG. STICKER MISSING/EXPIRED',
#        'ANNOY, SERIOUSLY; UNREASONABLE ALARM', 'STREET, SWEEP INTO',
#        'UNLICENSED GARAGE/PARKING LOT',
#        'PREVENT CLEAR VIEW INTO LIQUOR STORE',
#        'DOG FECES, FAIL TO REMOVE PROMPTLY (DOES NOT APPLY TO A GUIDE DOG)',
#        'BROKEN WINDSHIELD',
#        'FAIL TO DISPLAY HAIRSTYLIST/NAIL TECH/COSMETOLOGISTS LICENSE',
#        'OTHER MULTIPLE DWELLING', 'POLICE RADIO OR EQUIPMENT',
#        'NO COVERED GARBAGE, USED SOLELY FOR HAIR/PAPER/WASTE MATERIAL',
#        'UNLICENSED HAIRSTYLIST/NAIL TECH/COSMETOLOGIST',
#        'EXIT DOOR LESS THAN 36" WIDE', 'HAIR ON FLOOR',
#        'CARRY/POSSESS IN PUBLIC; UNLOADED & UNCONCEALED',
#        'WINDOW, AGAINST DISPLAY',
#        'DISGUISED IN AN UNLAWFUL MANNER WITHOUT REASON (MASKED)',
#        'LOITERING FOR DRUGS IN A PARK', 'DOING BUS W/OTHER NAME',
#        'PROHIBITED SALE', 'FAILURE TO TIMELY CREATE ELECTRONIC RECORD',
#        'FALSE LABELS ON MERCHANDISE',
#        'FAIL TO POST CIGARETTE HEALTH SIGNS', 'INSURANCE',
#        'CARRY/POSSESS IN PUBLIC; LOADED',
#        'EVICTION; UNLAWFUL (USE OR THREATEN THE USE OF FORCE)',
#        'UNAUTHORIZED RADIO',
#        'DESTINATION; FAIL TO PLACE & KEEP IN NON-RECORDING POSITION UNTIL PAID',
#        'UNLICENSED SIDEWALK CAF', 'WINDOW WASHER', 'IN A BUS STOP',
#        'UNSAFELY BACKING',
#        'GRAFFITI; SELL MARKER/SPRAY TO PERSON UNDER 21 YEARS OLD',
#        'PERMIT SEXUAL EXPOSURE', 'UNLICENSED STREET ENTERTAINER',
#        'GRAFFITI', "ENTRANCE, WITHIN 20 FT OF ANOTHER'S", nan,
#        'CAP ON PEDICABS', 'SAFETY BELT (ADULT)',
#        'POSSESSION OF A LASER POINTER (18 YRS OLD OR YOUNGER IN PUBLIC PLACE)',
#        'NO STANDING', 'NO CERTIFICATE OF FITNESS FOR TORCH',
#        'AGGRESSIVE PANHANDLING OF MOTOR VEHICLE OR AGGRESSIVE SALE',
#        'ENTRY FROM OTHER PORTION OF BUILDING', 'TICKET SPECULATION',
#        'DISCRIMINATION (REFUSE TO SELL)', 'SEX IN PARK',
#        'FENCED/ENCLOSED AREA, ALLOW CHILD/ANIMAL IN', 'SMOKING',
#        'BUSINESS SOLICITATION OF PEDESTRIANS BY PULLERS-IN (AGGRESSIVE)',
#        'DUMPING BY; OPERATOR OR OWNER OF A VEHICLE', 'ALLOW GAMBLING',
#        'NO STANDING (AUTH. VEHICLES)',
#        'METER OPERATING; TAMPER WITH METER/SEALS/CONNECTION/WIRING/TIRES TO AFFECT',
#        'DEFECTIVE; PICK-UP/TRANSPORT PASSENGERS WHEN',
#        'LIQUOR STORE FAILED TO PAINT LICENSE # ON FRONT WINDOW',
#        'SALE AFTER HOURS (4AM-12PM, SUN)', 'ANGLE PARKING',
#        'CAMPING WITHOUT A PERMIT', 'DISPLAY; UNLAWFULLY',
#        'REVOKED/SUSPENDED/EXPIRED, OPERATE WHILE',
#        'UNHYGIENIC USE OF THE FOUNTAIN OR POOL AREA',
#        'DOG: NO VACCINATION', 'OTHER AGRICULTURE & MARKETS LAW',
#        'FAIL TO MAINTAIN PROPRIETARYSECURITY GUARD LICENSE',
#        'PLACE/TIME PROHIBITED (SPECIFIC LOCATIONS & TIMES IN MANHATTAN)',
#        'OPERATE MOTOR VEHICLE AND FAILS TO USE DUE CARE FOR ANIMAL (B SUMMONS)',
#        'PEDICAB BUSINESS LICENSE',
#        'POSSESSION OF A LASER POINTER (20 YRS OLD OR YOUNGER ON SCHOOL PREMISES)',
#        'ENGINE IDLE; CAUSE/PERMIT MORE THAN 3 MINUTES',
#        'SWEEP ITEMS INTO STREET',
#        'OPENING ENTRIES; FAIL TO SIGN AND CERTIFY',
#        'VACANT LOT; TRAILER, AUTO/HOUSE, PARK',
#        'OVERCHARGE/ATTEMPT; FARE SET BY TLC', 'SAFETY ZONE', 'REPORTING',
#        'TOW:PD RADIO/SCANNR-TOW TRUCK/ON PERSON',
#        'ROLLER SKATE; OTHER THAN DESIGNATED AREA',
#        'PRICE, FAILS TO DISPLAY',
#        'USED PAPER TOWELS/PAPER/OTHER MATERIALS NOT IN GARBAGE',
#        'PARKING PROHIBITED, WHERE', 'TAXI-NO METER',
#        'REGISTRATION CERTIFICATE; POSSES WITHOUT',
#        'ALCOHOL BEVERAGE; CONSUME WHILE DRIVING/OCCUPYING',
#        'SMOKING ON A BUS', 'PERMIT; FAIL TO PROPERLY POST',
#        'UNREASONABLE NOISE; FROM AN ANIMAL(7AM-10PM)CONTINUOUSLY FOR 10MIN OR MORE',
#        'SIGNS, UNAUTHORIZED', 'FRAUDULENT ACCOSTING',
#        'VENDING: NO TAX STAMP',
#        'STREET NUMBERS NOT DISPLAYED PROPERLY; ANY BUILDING',
#        'SIDEWALK; DIRTY', 'NO STANDING (BUS STOP)',
#        'NOT IN A BIKE LANE OR IN THE RIGHT HAND SIDE OF TRAFFIC',
#        'LOITERING (MASKED/DISGUISE)', 'DOG IN PARK',
#        'LOST/STOLEN; FAIL TO NOTIFY WITHIN 72 HOURS',
#        'UNREASONABLE  SPEED', 'FENCED/ENCLOSED AREA, GO UPON',
#        'UNAUTHORIZED FOR HIRE', 'DISORDERLY BEHAVIOR (GAMBLING)',
#        'CARRY/EXHIBIT ON DEMAND (FAIL TO)',
#        'DESTINATION; REFUSE WITHOUT "JUSTIFIABLE GROUNDS"',
#        'PASSING ON RIGHT',
#        'SPEED/DRIVING DANGEROUS TO PASSENGER/PEDESTRIAN/OTHER VEHICLE',
#        'SIDEWALK; MERCHANDISE ON DISPLAY; OR IMPROPER STAND',
#        'LITTER BASKETS; IMPROPER USE OF',
#        'EQUIPMENT & MECHANICAL DEVICES; UNAUTHORIZED',
#        'FIREWORKS (POSSESS IN THE PARK)', 'RECEIPT, FAILS TO OFFER',
#        'POSSESSION AND SALE OF DRUG PARAPHERNALIA',
#        'FAILURE TO UPLOAD PHOTO', 'UNREASONABLE NOISE FROM AN ANIMAL',
#        'SMOKING IN TAXICAB', 'NOISE (ENGINE EXHAUST)',
#        'FAIL TO YIELD FOR EMERGENCY VEHICLE',
#        'OTHER GENERAL BUSINESS LAW', 'BUILDING; VEHICLE TOUCHING/LEANING',
#        'OBSTRUCTION OF VEHICLE/PEDESTRIAN TRAFFIC',
#        'FOR SALE SIGN DISPLAYED', 'LOITERING (BEGGING)',
#        'DESTROY PLANTS/TREES/SHRUBS/FLOWERS', 'NOISE (ANIMIAL)',
#        'TOPLESS FEMALE EMPLOYEE NOT ON STAGE',
#        'CRUISING PROHIBITED - MEDALLION', 'SUBWAY; WITHIN 10 FEET OF',
#        'U-TURN', 'REPAIRS, FAIL TO MAKE REQUIRED ENTRIES REGARDING',
#        'UNLICENSED RESALE, TRANSFER GOODS/VEHICLE FOR',
#        'UNINSURED VEHICLES FOR HIRE', 'CROSSED DOUBLE YELLOW TO PASS',
#        'EMPLOYER ALLOW FEMALE EMPLOYEE TOPLESS & NOT ON STAGE',
#        'HAZING 2', 'VIOLATE RESTRICTED USE LICENSE', 'CRUISING',
#        'VENDING ON PARKING METER', 'LOITERING (SEXUAL CONDUCT)',
#        'VENDOR: OVERSIZE TABLE', 'INSPECTION STKR. (MISSING/EXPIRED)',
#        'MISSING/IMPROPER PLATES', 'NOISE (ANIMAL)', 'INTERSECTION',
#        'FAIL TO YIELD AT LEFT TURN', 'UNAUTHORIZED COLOR (TAXI YELLOW)',
#        'BICYCLE NO SAFETY HELMET', 'MOTORCYCLE (OTHER)',
#        'OBSTRUCTING DRIVEWAY', 'MISUSE OF DEALER PLATES',
#        'MOTORCYCLE HELMET REQUIRED', 'TRUANCY', 'WRONG WAY', 'SPEEDING',
#        'DRIVE THRU BARRIER', 'VIOLATE LEARNERS PERMIT',
#        'WINDSHIELD WASHERS', 'NO VENDING MACH. DISCLOSURE',
#        'BICYCLE NO REFLECTOR VEST', 'NO STANDING (BUS LANE)',
#        'NO PARKING (STREET CLEANING)',
#        'RIDING IN OTHER THAN PASSENGER COMPARTMENT'], dtype=object)
